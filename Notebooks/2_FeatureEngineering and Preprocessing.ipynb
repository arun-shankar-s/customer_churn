# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("../data/raw/Telco-Customer-Churn.csv")

# %%
df.columns = df.columns.str.strip().str.replace(" ", "").str.lower()

# %%
df['churn'] = df['churn'].astype(str).str.title().str.strip()
df['churn'] = df['churn'].map({'Yes':1, 'No':0})

# %%
df['totalcharges'] = pd.to_numeric(df['totalcharges'], errors='coerce')

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
df = df.fillna({
    col: df[col].mode()[0] if df[col].dtype == 'object' else df[col].median()
    for col in df.columns
})

# %%
df = df.drop(['customerid'], axis=1)

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()
num_cols.remove('churn')  # remove target

cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
num_cols = ['tenure', 'monthlycharges', 'totalcharges']
cat_cols = [col for col in df.columns if df[col].dtype == 'object' and col != 'churn']

# %%
# One-hot encode categorical features
# pd.get_dummies() converts categorical features into one-hot encoded numeric columns, making them usable for ML models.
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
df.shape, df_encoded.shape
# Out:
# ((7043, 21), (7043, 7073))

# %%
df_encoded.columns
# Out:
# Index(['seniorcitizen', 'tenure', 'monthlycharges', 'totalcharges', 'churn',
#        'gender_Male', 'partner_Yes', 'dependents_Yes', 'phoneservice_Yes',
#        'multiplelines_No phone service', 'multiplelines_Yes',
#        'internetservice_Fiber optic', 'internetservice_No',
#        'onlinesecurity_No internet service', 'onlinesecurity_Yes',
#        'onlinebackup_No internet service', 'onlinebackup_Yes',
#        'deviceprotection_No internet service', 'deviceprotection_Yes',
#        'techsupport_No internet service', 'techsupport_Yes',
#        'streamingtv_No internet service', 'streamingtv_Yes',
#        'streamingmovies_No internet service', 'streamingmovies_Yes',
#        'contract_One year', 'contract_Two year', 'paperlessbilling_Yes',
#        'paymentmethod_Credit card (automatic)',
#        'paymentmethod_Electronic check', 'paymentmethod_Mailed check'],
#       dtype='object')

# %%
[x for x in df_encoded.columns if "_" in x]
# Out:
# ['customerid_0003-MKNFE',
#  'customerid_0004-TLHLJ',
#  'customerid_0011-IGKFF',
#  'customerid_0013-EXCHZ',
#  'customerid_0013-MHZWF',
#  'customerid_0013-SMEOE',
#  'customerid_0014-BMAQU',
#  'customerid_0015-UOCOJ',
#  'customerid_0016-QLJIS',
#  'customerid_0017-DINOC',
#  'customerid_0017-IUDMW',
#  'customerid_0018-NYROU',
#  'customerid_0019-EFAEP',
#  'customerid_0019-GFNTW',
#  'customerid_0020-INWCK',
#  'customerid_0020-JDNXP',
#  'customerid_0021-IKXGC',
#  'customerid_0022-TCJCI',
#  'customerid_0023-HGHWL',
#  'customerid_0023-UYUPN',
#  'customerid_0023-XUOPT',
#  'customerid_0027-KWYKW',
#  'customerid_0030-FNXPP',
#  'customerid_0031-PVLZI',
#  'customerid_0032-PGELS',
#  'customerid_0036-IHMOT',
#  'customerid_0040-HALCW',
#  'customerid_0042-JVWOJ',
#  'customerid_0042-RLHYP',
#  'customerid_0048-LUMLS',
#  'customerid_0048-PIHNL',
#  'customerid_0052-DCKON',
#  'customerid_0052-YNYOT',
#  'customerid_0056-EPFBG',
#  'customerid_0057-QBUQH',
#  'customerid_0058-EVZWM',
#  'customerid_0060-FUALY',
#  'customerid_0064-SUDOG',
#  'customerid_0064-YIJGF',
#  'customerid_0067-DKWBL',
#  'customerid_0068-FIGTF',
#  'customerid_0071-NDAFP',
#  'customerid_0074-HDKDG',
#  'customerid_0076-LVEPS',
#  'customerid_0078-XZMHT',
#  'customerid_0080-EMYVY',
#  'customerid_0080-OROZO',
#  'customerid_0082-LDZUE',
#  'customerid_0082-OQIQY',
#  'customerid_0083-PIVIK',
#  'customerid_0089-IIQKO',
#  'customerid_0093-EXYQL',
#  'customerid_0093-XWZFY',
#  'customerid_0094-OIFMO',
#  'customerid_0096-BXERS',
#  'customerid_0096-FCPUF',
#  'customerid_0098-BOWSO',
#  'customerid_0100-DUVFC',
#  'customerid_0103-CSITQ',
#  'customerid_0104-PPXDV',
#  'customerid_0106-GHRQR',
#  'customerid_0106-UGRDO',
#  'customerid_0107-WESLM',
#  'customerid_0107-YHINA',
#  'customerid_0111-KLBQG',
#  'customerid_0112-QAWRZ',
#  'customerid_0112-QWPNC',
#  'customerid_0114-IGABW',
#  'customerid_0114-PEGZZ',
#  'customerid_0114-RSRRW',
#  'customerid_0115-TFERT',
#  'customerid_0117-LFRMW',
#  'customerid_0118-JPNOY',
#  'customerid_0121-SNYRK',
#  'customerid_0122-OAHPZ',
#  'customerid_0123-CRBRT',
#  'customerid_0125-LZQXK',
#  'customerid_0128-MKWSG',
#  'customerid_0129-KPTWJ',
#  'customerid_0129-QMPDR',
#  'customerid_0130-SXOUN',
#  'customerid_0133-BMFZO',
#  'customerid_0134-XWXCE',
#  'customerid_0135-NMXAP',
#  'customerid_0136-IFMYD',
#  'customerid_0137-OCGAB',
#  'customerid_0137-UDEUO',
#  'customerid_0139-IVFJG',
#  'customerid_0141-YEAYS',
#  'customerid_0142-GVYSN',
#  'customerid_0147-ESWWR',
#  'customerid_0148-DCDOS',
#  'customerid_0151-ONTOV',
#  'customerid_0156-FVPTA',
#  'customerid_0164-APGRB',
#  'customerid_0164-XAIRP',
#  'customerid_0168-XZKBB',
#  'customerid_0174-QRVVY',
#  'customerid_0177-PXBAT',
#  'customerid_0178-CIIKR',
#  'customerid_0178-SZBHO',
#  'customerid_0181-RITDD',
#  'customerid_0186-CAERR',
#  'customerid_0187-QSXOE',
#  'customerid_0187-WZNAB',
#  'customerid_0188-GWFLE',
#  'customerid_0191-EQUUH',
#  'customerid_0191-ZHSKZ',
#  'customerid_0193-ESZXP',
#  'customerid_0195-IESCP',
#  'customerid_0196-JTUQI',
#  'customerid_0196-VULGZ',
#  'customerid_0197-PNKNK',
#  'customerid_0201-MIBOL',
#  'customerid_0201-OAMXR',
#  'customerid_0203-HHYIJ',
#  'customerid_0206-OYVOC',
#  'customerid_0206-TBWLC',
#  'customerid_0207-MDKNV',
#  'customerid_0208-BPQEJ',
#  'customerid_0212-ISBBF',
#  'customerid_0214-JHPFW',
#  'customerid_0215-BQKGS',
#  'customerid_0218-QNVAS',
#  'customerid_0219-QAERP',
#  'customerid_0219-YTZUE',
#  'customerid_0220-EBGCE',
#  'customerid_0221-NAUXK',
#  'customerid_0221-WMXNQ',
#  'customerid_0222-CNVPT',
#  'customerid_0224-HJAPT',
#  'customerid_0224-NIJLP',
#  'customerid_0224-RLWWD',
#  'customerid_0225-ZORZP',
#  'customerid_0228-MAUWC',
#  'customerid_0229-LFJAF',
#  'customerid_0230-UBYPQ',
#  'customerid_0230-WEQUW',
#  'customerid_0231-LXVAP',
#  'customerid_0233-FTHAV',
#  'customerid_0234-TEVTT',
#  'customerid_0235-KGSLC',
#  'customerid_0236-HFWSV',
#  'customerid_0237-YFUTL',
#  'customerid_0238-WHBIQ',
#  'customerid_0239-OXEXL',
#  'customerid_0244-LGNFY',
#  'customerid_0247-SLUJI',
#  'customerid_0248-IPDFW',
#  'customerid_0248-PGHBZ',
#  'customerid_0253-ZTEOB',
#  'customerid_0254-FNMCI',
#  'customerid_0254-KCJGT',
#  'customerid_0254-WWRKD',
#  'customerid_0256-LTHVJ',
#  'customerid_0257-KXZGU',
#  'customerid_0257-ZESQC',
#  'customerid_0258-NOKBL',
#  'customerid_0259-GBZSH',
#  'customerid_0260-ZDLGK',
#  'customerid_0263-FJTQO',
#  'customerid_0264-CNITK',
#  'customerid_0265-EDXBD',
#  'customerid_0265-PSUAE',
#  'customerid_0266-CLZKZ',
#  'customerid_0266-GMEAO',
#  'customerid_0268-QKIWO',
#  'customerid_0269-XFESX',
#  'customerid_0270-THENM',
#  'customerid_0274-JKUJR',
#  'customerid_0277-BKSQP',
#  'customerid_0277-ORXQS',
#  'customerid_0278-YXOOG',
#  'customerid_0280-XJGEX',
#  'customerid_0281-CNTZX',
#  'customerid_0282-NVSJS',
#  'customerid_0285-INHLN',
#  'customerid_0289-IVARM',
#  'customerid_0292-WEGCH',
#  'customerid_0295-PPHDO',
#  'customerid_0295-QVKPB',
#  'customerid_0297-RBCSG',
#  'customerid_0298-XACET',
#  'customerid_0301-FIDRB',
#  'customerid_0301-KOBTQ',
#  'customerid_0302-JOIVN',
#  'customerid_0303-UNCIP',
#  'customerid_0303-WMMRN',
#  'customerid_0305-SQECB',
#  'customerid_0306-JAELE',
#  'customerid_0307-BCOPK',
#  'customerid_0308-GIQJT',
#  'customerid_0308-IVGOK',
#  'customerid_0310-MVLET',
#  'customerid_0310-SUCIN',
#  'customerid_0310-VQXAM',
#  'customerid_0311-QYWSS',
#  'customerid_0311-UNPFF',
#  'customerid_0314-TKOSI',
#  'customerid_0315-LVCRK',
#  'customerid_0318-QUUOB',
#  'customerid_0318-ZOPWS',
#  'customerid_0319-QZTCO',
#  'customerid_0320-DWVTU',
#  'customerid_0320-JDNQG',
#  'customerid_0322-CHQRU',
#  'customerid_0322-YINQP',
#  'customerid_0323-XWWTN',
#  'customerid_0324-BRPCJ',
#  'customerid_0325-XBFAC',
#  'customerid_0326-VDYXE',
#  'customerid_0327-WFZSY',
#  'customerid_0328-GRPMV',
#  'customerid_0329-GTIAJ',
#  'customerid_0330-BGYZE',
#  'customerid_0330-IVZHA',
#  'customerid_0334-GDDSO',
#  'customerid_0334-ZFJSR',
#  'customerid_0336-KXKFK',
#  'customerid_0336-PIKEI',
#  'customerid_0337-CNPZE',
#  'customerid_0343-QLUZP',
#  'customerid_0345-HKJVM',
#  'customerid_0345-XMMUG',
#  'customerid_0347-UBKUZ',
#  'customerid_0348-SDKOL',
#  'customerid_0354-VXMJC',
#  'customerid_0354-WYROK',
#  'customerid_0356-ERHVT',
#  'customerid_0356-OBMAC',
#  'customerid_0357-NVCRI',
#  'customerid_0361-HJRDX',
#  'customerid_0362-RAOQO',
#  'customerid_0362-ZBZWJ',
#  'customerid_0363-QJVFX',
#  'customerid_0363-SVHYR',
#  'customerid_0365-BZUWY',
#  'customerid_0365-GXEZS',
#  'customerid_0365-TRTPY',
#  'customerid_0366-NQSHS',
#  'customerid_0369-ZGOVK',
#  'customerid_0373-AIVNJ',
#  'customerid_0374-AACSZ',
#  'customerid_0374-FIUCA',
#  'customerid_0374-IOEGQ',
#  'customerid_0375-HVGXO',
#  'customerid_0376-OIWME',
#  'customerid_0376-YMCJC',
#  'customerid_0377-JBKKT',
#  'customerid_0378-CJKPV',
#  'customerid_0378-NHQXU',
#  'customerid_0378-TOVMS',
#  'customerid_0378-XSZPU',
#  'customerid_0379-DJQHR',
#  'customerid_0380-NEAVX',
#  'customerid_0380-ZCSBI',
#  'customerid_0383-CLDDA',
#  'customerid_0384-LPITE',
#  'customerid_0384-RVBPI',
#  'customerid_0386-CWRGM',
#  'customerid_0388-EOPEX',
#  'customerid_0390-DCFDQ',
#  'customerid_0392-BZIUW',
#  'customerid_0394-YONDK',
#  'customerid_0396-HUJBP',
#  'customerid_0396-UKGAI',
#  'customerid_0396-YCHWO',
#  'customerid_0397-GZBBC',
#  'customerid_0397-ZXWQF',
#  'customerid_0401-WDBXM',
#  'customerid_0402-CQAJN',
#  'customerid_0402-OAMEN',
#  'customerid_0404-AHASP',
#  'customerid_0404-SWRVG',
#  'customerid_0406-BPDVR',
#  'customerid_0407-BDJKB',
#  'customerid_0409-WTMPL',
#  'customerid_0410-IPFTY',
#  'customerid_0411-EZJZE',
#  'customerid_0412-UCCNP',
#  'customerid_0415-MOSGF',
#  'customerid_0419-YAAPX',
#  'customerid_0420-BWTPW',
#  'customerid_0420-HLGXF',
#  'customerid_0420-TXVSG',
#  'customerid_0422-OHQHQ',
#  'customerid_0422-UXFAP',
#  'customerid_0423-UDIJQ',
#  'customerid_0426-TIRNE',
#  'customerid_0428-AXXLJ',
#  'customerid_0428-IKYCP',
#  'customerid_0430-IHCDJ',
#  'customerid_0431-APWVY',
#  'customerid_0432-CAJZV',
#  'customerid_0434-CSFON',
#  'customerid_0436-TWFFZ',
#  'customerid_0439-IFYUN',
#  'customerid_0440-EKDCF',
#  'customerid_0440-MOGPM',
#  'customerid_0440-QEXBZ',
#  'customerid_0440-UEDAI',
#  'customerid_0442-TDYUO',
#  'customerid_0442-ZXKVS',
#  'customerid_0447-BEMNG',
#  'customerid_0447-RXSGD',
#  'customerid_0454-OKRCT',
#  'customerid_0455-ENTCR',
#  'customerid_0455-XFASS',
#  'customerid_0458-HEUZG',
#  'customerid_0459-SPZHJ',
#  'customerid_0461-CVKMU',
#  'customerid_0463-TXOAK',
#  'customerid_0463-WZZKO',
#  'customerid_0463-ZSDNT',
#  'customerid_0464-WJTKO',
#  'customerid_0468-YRPXN',
#  'customerid_0471-ARVMX',
#  'customerid_0471-LVHGK',
#  'customerid_0475-RIJEP',
#  'customerid_0479-HMSWA',
#  'customerid_0480-BIXDE',
#  'customerid_0480-KYJVA',
#  'customerid_0481-SUMCB',
#  'customerid_0484-FFVBJ',
#  'customerid_0484-JPBRU',
#  'customerid_0485-ZBSLN',
#  'customerid_0486-HECZI',
#  'customerid_0486-LGCCH',
#  'customerid_0487-CRLZF',
#  'customerid_0487-RPVUM',
#  'customerid_0487-VVUVK',
#  'customerid_0488-GSLFR',
#  'customerid_0489-WMEMG',
#  'customerid_0491-KAPQG',
#  'customerid_0495-RVCBF',
#  'customerid_0495-ZBNGW',
#  'customerid_0496-AHOOK',
#  'customerid_0504-HHAPI',
#  'customerid_0505-SPOOW',
#  'customerid_0506-LVNGN',
#  'customerid_0506-YLVKJ',
#  'customerid_0508-OOLTO',
#  'customerid_0508-SQWPL',
#  'customerid_0511-JTEOY',
#  'customerid_0512-FLFDW',
#  'customerid_0513-RBGPE',
#  'customerid_0515-YPMCW',
#  'customerid_0516-OOHAR',
#  'customerid_0516-QREYC',
#  'customerid_0516-UXRMT',
#  'customerid_0516-VRYBW',
#  'customerid_0516-WJVXC',
#  'customerid_0519-DRGTI',
#  'customerid_0519-XUZJU',
#  'customerid_0520-FDVVT',
#  'customerid_0523-VNGTF',
#  'customerid_0524-IAVZO',
#  'customerid_0526-SXDJP',
#  'customerid_0529-ONKER',
#  'customerid_0530-IJVDB',
#  'customerid_0531-XBKMM',
#  'customerid_0531-ZZJWQ',
#  'customerid_0533-BNWKF',
#  'customerid_0533-UCAAU',
#  'customerid_0536-ACXIP',
#  'customerid_0536-BGFMZ',
#  'customerid_0536-ESJEP',
#  'customerid_0537-QYZZN',
#  'customerid_0541-FITGH',
#  'customerid_0547-HURJB',
#  'customerid_0549-CYCQN',
#  'customerid_0550-DCXLH',
#  'customerid_0556-FJEGU',
#  'customerid_0557-ASKVU',
#  'customerid_0559-CKHUS',
#  'customerid_0562-FGDCR',
#  'customerid_0562-HKHML',
#  'customerid_0562-KBDVM',
#  'customerid_0564-JJHGS',
#  'customerid_0564-MUUQK',
#  'customerid_0565-IYCGT',
#  'customerid_0565-JUPYD',
#  'customerid_0567-GGCAC',
#  'customerid_0567-XRHCU',
#  'customerid_0568-ONFPC',
#  'customerid_0570-BFQHT',
#  'customerid_0572-ZJKLT',
#  'customerid_0575-CUQOV',
#  'customerid_0576-WNXXC',
#  'customerid_0577-WHMEV',
#  'customerid_0578-SKVMF',
#  'customerid_0580-PIQHM',
#  'customerid_0581-BXBUB',
#  'customerid_0581-MDMPW',
#  'customerid_0582-AVCLN',
#  'customerid_0584-BJQGZ',
#  'customerid_0585-EGDDA',
#  'customerid_0587-DMGBH',
#  'customerid_0594-UFTUL',
#  'customerid_0595-ITUDF',
#  'customerid_0596-BQCEQ',
#  'customerid_0599-XNYDO',
#  'customerid_0601-WZHJF',
#  'customerid_0602-DDUML',
#  'customerid_0603-OLQDC',
#  'customerid_0603-TPMIB',
#  'customerid_0604-THJFP',
#  'customerid_0607-DAAHE',
#  'customerid_0607-MVMGC',
#  'customerid_0608-JDVEC',
#  'customerid_0611-DFXKO',
#  'customerid_0612-RTZZA',
#  'customerid_0613-WUXUM',
#  'customerid_0616-ATFGB',
#  'customerid_0617-AQNWT',
#  'customerid_0617-FHSGK',
#  'customerid_0618-XWMSS',
#  'customerid_0619-OLYUR',
#  'customerid_0620-DLSLK',
#  'customerid_0620-XEFWH',
#  'customerid_0621-CXBKL',
#  'customerid_0621-HJWXJ',
#  'customerid_0621-JFHOL',
#  'customerid_0621-TSSMU',
#  'customerid_0621-TWIEM',
#  'customerid_0623-EJQEG',
#  'customerid_0623-GDISB',
#  'customerid_0623-IIHUG',
#  'customerid_0625-AFOHS',
#  'customerid_0626-QXNGV',
#  'customerid_0628-CNQRM',
#  'customerid_0634-SZPQA',
#  'customerid_0635-WKOLD',
#  'customerid_0637-KVDLV',
#  'customerid_0637-UBJRP',
#  'customerid_0637-YLETY',
#  'customerid_0639-TSIQW',
#  'customerid_0640-YJTPY',
#  'customerid_0641-EVBOJ',
#  'customerid_0643-OKLRP',
#  'customerid_0644-OQMDK',
#  'customerid_0650-BWOZN',
#  'customerid_0654-HMSHN',
#  'customerid_0654-PQKDW',
#  'customerid_0655-RBDUG',
#  'customerid_0655-YDGFJ',
#  'customerid_0657-DOGUM',
#  'customerid_0661-KBKPA',
#  'customerid_0661-KQHNK',
#  'customerid_0661-WCQNQ',
#  'customerid_0661-XEYAN',
#  'customerid_0665-XHDJU',
#  'customerid_0666-UXTJO',
#  'customerid_0667-NSRGI',
#  'customerid_0668-OGMHD',
#  'customerid_0670-ANMUU',
#  'customerid_0670-KDOMA',
#  'customerid_0673-IGUQO',
#  'customerid_0674-DGMAQ',
#  'customerid_0674-EYYZV',
#  'customerid_0674-GCDXG',
#  'customerid_0675-NCDYU',
#  'customerid_0678-RLHVP',
#  'customerid_0679-IDSTG',
#  'customerid_0679-TDGAK',
#  'customerid_0680-DFNNY',
#  'customerid_0682-USIXD',
#  'customerid_0684-AOSIH',
#  'customerid_0685-MLYYM',
#  'customerid_0687-ZVTHB',
#  'customerid_0689-DSXGL',
#  'customerid_0689-NKYLF',
#  'customerid_0690-SRQID',
#  'customerid_0691-IFBQW',
#  'customerid_0691-JVSYA',
#  'customerid_0691-NIKRI',
#  'customerid_0696-UKTOX',
#  'customerid_0697-ZMSWS',
#  'customerid_0699-NDKJM',
#  'customerid_0701-RFGFI',
#  'customerid_0701-TJSEF',
#  'customerid_0702-PGIBZ',
#  'customerid_0704-VCUMB',
#  'customerid_0707-HOVVN',
#  'customerid_0708-LGSMF',
#  'customerid_0708-SJDIS',
#  'customerid_0709-TVGUR',
#  'customerid_0716-BQNDX',
#  'customerid_0719-SYFRB',
#  'customerid_0722-SVSFK',
#  'customerid_0722-TROQR',
#  'customerid_0723-DRCLG',
#  'customerid_0723-FDLAY',
#  'customerid_0723-VSOBE',
#  'customerid_0725-CXOTM',
#  'customerid_0727-BMPLR',
#  'customerid_0727-BNRLG',
#  'customerid_0727-IWKVK',
#  'customerid_0730-BGQGF',
#  'customerid_0730-KOAVE',
#  'customerid_0731-EBJQB',
#  'customerid_0732-OCQOC',
#  'customerid_0733-VUNUW',
#  'customerid_0734-OXWBT',
#  'customerid_0739-UUAJR',
#  'customerid_0742-LAFQK',
#  'customerid_0742-MOABM',
#  'customerid_0742-NXBGR',
#  'customerid_0743-HNPFG',
#  'customerid_0743-HRVFF',
#  'customerid_0744-BIKKF',
#  'customerid_0744-GKNGE',
#  'customerid_0746-JTRFU',
#  'customerid_0748-RDGGM',
#  'customerid_0749-IRGQE',
#  'customerid_0750-EBAIU',
#  'customerid_0750-EKNGL',
#  'customerid_0754-EEBDC',
#  'customerid_0754-UKWQP',
#  'customerid_0756-MPZRL',
#  'customerid_0757-WCUUZ',
#  'customerid_0761-AETCS',
#  'customerid_0769-MURVM',
#  'customerid_0771-CHWSK',
#  'customerid_0771-WLCLA',
#  'customerid_0772-GYEQQ',
#  'customerid_0774-IFUVM',
#  'customerid_0774-RMNUW',
#  'customerid_0778-NELLA',
#  'customerid_0780-XNZFN',
#  'customerid_0781-LKXBR',
#  'customerid_0784-GTUUK',
#  'customerid_0784-ZQJZX',
#  'customerid_0786-IVLAW',
#  'customerid_0786-VSSUD',
#  'customerid_0787-LHDYT',
#  'customerid_0788-DXBFY',
#  'customerid_0793-TWELN',
#  'customerid_0794-YVSGE',
#  'customerid_0795-GMVQO',
#  'customerid_0795-LAFGP',
#  'customerid_0795-XCCTE',
#  'customerid_0799-DDIHE',
#  'customerid_0804-XBFBV',
#  'customerid_0804-YGEQV',
#  'customerid_0807-ZABDG',
#  'customerid_0810-BDHAW',
#  'customerid_0810-DHDBD',
#  'customerid_0811-GSDTP',
#  'customerid_0812-WUPTB',
#  'customerid_0813-TAXXS',
#  'customerid_0815-MFZGM',
#  'customerid_0816-TSPHQ',
#  'customerid_0817-HSUSE',
#  'customerid_0818-OCPZO',
#  'customerid_0820-FNRNX',
#  'customerid_0822-GAVAP',
#  'customerid_0822-QGCXA',
#  'customerid_0823-HSCDJ',
#  'customerid_0824-VWDPO',
#  'customerid_0825-CPPQH',
#  'customerid_0827-ITJPH',
#  'customerid_0829-DDVLK',
#  'customerid_0829-XXPLX',
#  'customerid_0831-JNISG',
#  'customerid_0835-DUUIQ',
#  'customerid_0835-JKADZ',
#  'customerid_0836-SEYLU',
#  'customerid_0839-JTCUD',
#  'customerid_0839-QNXME',
#  'customerid_0840-DCNZE',
#  'customerid_0840-DFEZH',
#  'customerid_0841-NULXI',
#  'customerid_0842-IWYCP',
#  'customerid_0843-WTBXE',
#  'customerid_0847-HGRML',
#  'customerid_0848-SOMKO',
#  'customerid_0848-ZGQIJ',
#  'customerid_0851-DFJKB',
#  'customerid_0853-NWIFK',
#  'customerid_0853-TWRVK',
#  'customerid_0854-UYHZD',
#  'customerid_0856-NAOES',
#  'customerid_0859-YGKFW',
#  'customerid_0862-PRCBS',
#  'customerid_0864-FVJNJ',
#  'customerid_0866-QLSIR',
#  'customerid_0867-LDTTC',
#  'customerid_0867-MKZVY',
#  'customerid_0868-VJRDR',
#  'customerid_0869-PAPRP',
#  'customerid_0870-VEMYL',
#  'customerid_0871-OPBXW',
#  'customerid_0871-URUWO',
#  'customerid_0872-CASZJ',
#  'customerid_0872-JCPIB',
#  'customerid_0872-NXJYS',
#  'customerid_0875-CABNR',
#  'customerid_0876-WDUUZ',
#  'customerid_0877-SDMBN',
#  'customerid_0880-FVFWF',
#  'customerid_0880-TKATG',
#  'customerid_0883-EIBTI',
#  'customerid_0885-HMGPY',
#  'customerid_0886-QGENL',
#  'customerid_0887-HJGAR',
#  'customerid_0887-WBJVH',
#  'customerid_0895-DQHEW',
#  'customerid_0895-LMRSF',
#  'customerid_0895-LNKRC',
#  'customerid_0895-UADGO',
#  'customerid_0897-FEGMU',
#  'customerid_0898-XCGTF',
#  'customerid_0899-LIIBW',
#  'customerid_0899-WZRSD',
#  'customerid_0902-RFHOF',
#  'customerid_0902-XKXPN',
#  'customerid_0906-QVPMS',
#  'customerid_0907-HQNTS',
#  'customerid_0909-SDHNU',
#  'customerid_0909-SELIE',
#  'customerid_0913-XWSCN',
#  'customerid_0916-KNFAJ',
#  'customerid_0916-QOFDP',
#  'customerid_0917-EZOLA',
#  'customerid_0921-OHLVP',
#  'customerid_0923-PNFUB',
#  'customerid_0924-BJCRC',
#  'customerid_0925-VYDLG',
#  'customerid_0927-CNGRH',
#  'customerid_0927-LCSMG',
#  'customerid_0928-JMXNP',
#  'customerid_0928-XUTSN',
#  'customerid_0929-HYQEW',
#  'customerid_0929-PECLO',
#  'customerid_0930-EHUZA',
#  'customerid_0931-MHTEM',
#  'customerid_0932-YIXYU',
#  'customerid_0936-NQLJU',
#  'customerid_0939-EREMR',
#  'customerid_0939-YAPAF',
#  'customerid_0940-OUQEC',
#  'customerid_0942-KOWSM',
#  'customerid_0943-ZQPXH',
#  'customerid_0945-TSONX',
#  'customerid_0946-CLJTI',
#  'customerid_0946-FKYTX',
#  'customerid_0947-IDHRQ',
#  'customerid_0947-MUGVO',
#  'customerid_0952-KMEEH',
#  'customerid_0953-LGOVU',
#  'customerid_0956-ACVZC',
#  'customerid_0956-SYCWG',
#  'customerid_0958-YHXGP',
#  'customerid_0959-WHOKV',
#  'customerid_0960-HUWBM',
#  'customerid_0961-ZWLVI',
#  'customerid_0962-CQPWQ',
#  'customerid_0963-ZBDRN',
#  'customerid_0967-BMLBD',
#  'customerid_0968-GSIKN',
#  'customerid_0969-RGKCU',
#  'customerid_0970-ETWGE',
#  'customerid_0970-QXPXW',
#  'customerid_0971-QIFJK',
#  'customerid_0973-KYVNF',
#  'customerid_0975-UYDTX',
#  'customerid_0975-VOOVL',
#  'customerid_0979-MOZQI',
#  'customerid_0979-PHULV',
#  'customerid_0980-FEXWF',
#  'customerid_0980-PVMRC',
#  'customerid_0983-TATYJ',
#  'customerid_0988-AADSA',
#  'customerid_0988-JRWWP',
#  'customerid_0991-BRRFB',
#  'customerid_0993-OSGPT',
#  'customerid_0997-YTLNY',
#  'customerid_0999-QXNSA',
#  'customerid_1000-AJSLD',
#  'customerid_1004-NOZNR',
#  'customerid_1009-IRMNA',
#  'customerid_1010-DIAUQ',
#  'customerid_1013-QCWAM',
#  'customerid_1015-JPFYW',
#  'customerid_1015-OWJKI',
#  'customerid_1016-DJTSV',
#  'customerid_1017-FBQMM',
#  'customerid_1020-JPQOW',
#  'customerid_1022-RKXDR',
#  'customerid_1023-BQXZE',
#  'customerid_1024-GUALD',
#  'customerid_1024-KPRBB',
#  'customerid_1024-VRZHF',
#  'customerid_1025-FALIX',
#  'customerid_1027-LKKQQ',
#  'customerid_1028-FFNJK',
#  'customerid_1029-QFBEN',
#  'customerid_1031-IIDEO',
#  'customerid_1032-MAELW',
#  'customerid_1035-IPQPU',
#  'customerid_1036-GUDCL',
#  'customerid_1038-RQOST',
#  'customerid_1038-ZAGBI',
#  'customerid_1041-RXHRA',
#  'customerid_1042-HFUCW',
#  'customerid_1043-UXOVO',
#  'customerid_1043-YCUTE',
#  'customerid_1045-LTCYT',
#  'customerid_1047-NNCBF',
#  'customerid_1047-RNXZV',
#  'customerid_1049-FYSYG',
#  'customerid_1051-EQPZR',
#  'customerid_1051-GEJLJ',
#  'customerid_1052-QJIBV',
#  'customerid_1053-MXTTK',
#  'customerid_1057-FOGLZ',
#  'customerid_1060-ENTOF',
#  'customerid_1061-PNTHC',
#  'customerid_1062-LHZOD',
#  'customerid_1063-DHQJF',
#  'customerid_1064-FBXNK',
#  'customerid_1066-JKSGK',
#  'customerid_1069-QJOEE',
#  'customerid_1069-XAIEM',
#  'customerid_1073-XXCZD',
#  'customerid_1074-AMIOH',
#  'customerid_1074-WVEVG',
#  'customerid_1075-BGWOH',
#  'customerid_1077-HUUJM',
#  'customerid_1078-TDCRN',
#  'customerid_1080-BWSYE',
#  'customerid_1084-MNSMJ',
#  'customerid_1084-UQCHV',
#  'customerid_1085-LDWAM',
#  'customerid_1086-LXKFY',
#  'customerid_1087-GRUYI',
#  'customerid_1087-UDSIH',
#  'customerid_1088-AUUZZ',
#  'customerid_1088-CNNKB',
#  'customerid_1089-HDMKP',
#  'customerid_1089-XZWHH',
#  'customerid_1090-ESELR',
#  'customerid_1090-PYKCI',
#  'customerid_1091-SOZGA',
#  'customerid_1092-GANHU',
#  'customerid_1092-WPIVQ',
#  'customerid_1093-YSWCA',
#  'customerid_1094-BKOSX',
#  'customerid_1095-JUDTC',
#  'customerid_1095-WGNGG',
#  'customerid_1096-ADRUX',
#  'customerid_1097-FSPVW',
#  'customerid_1098-KFQEC',
#  'customerid_1098-TDVUQ',
#  'customerid_1099-BTKWT',
#  'customerid_1099-GODLO',
#  'customerid_1100-DDVRV',
#  'customerid_1101-SSWAG',
#  'customerid_1104-FEJAM',
#  'customerid_1104-TNLZA',
#  'customerid_1106-HRLKZ',
#  'customerid_1110-KYLGQ',
#  'customerid_1112-CUNAO',
#  'customerid_1113-IUJYX',
#  'customerid_1114-CENIM',
#  'customerid_1116-DXXDF',
#  'customerid_1116-FRYVH',
#  'customerid_1120-BMWUB',
#  'customerid_1121-QSIVB',
#  'customerid_1122-JWTJW',
#  'customerid_1122-YJBCS',
#  'customerid_1125-SNVCK',
#  'customerid_1131-ALZWV',
#  'customerid_1131-QQZEB',
#  'customerid_1131-SUEKT',
#  'customerid_1133-KXCGE',
#  'customerid_1134-YWTYF',
#  'customerid_1135-HIORI',
#  'customerid_1135-LMECX',
#  'customerid_1136-XGEQU',
#  'customerid_1137-DGOWI',
#  'customerid_1139-WUOAH',
#  'customerid_1140-UKVZG',
#  'customerid_1142-IHLOO',
#  'customerid_1142-WACZW',
#  'customerid_1143-NMNQJ',
#  'customerid_1150-FTQGN',
#  'customerid_1150-WFARN',
#  'customerid_1153-GNOLC',
#  'customerid_1154-HYWWO',
#  'customerid_1156-ZFYDO',
#  'customerid_1157-BQCUW',
#  'customerid_1159-WFSGR',
#  'customerid_1162-ECVII',
#  'customerid_1163-ONYEY',
#  'customerid_1163-VIPRI',
#  'customerid_1166-PQLGG',
#  'customerid_1167-OYZJF',
#  'customerid_1169-SAOCL',
#  'customerid_1169-WCVAK',
#  'customerid_1170-SASML',
#  'customerid_1171-TYKUR',
#  'customerid_1172-VIYBP',
#  'customerid_1173-NOEYG',
#  'customerid_1173-XZPYF',
#  'customerid_1174-FGIFN',
#  'customerid_1177-XZBJL',
#  'customerid_1178-PZGAB',
#  'customerid_1179-INLAT',
#  'customerid_1183-CANVH',
#  'customerid_1184-PJVDB',
#  'customerid_1187-WILMM',
#  'customerid_1193-RTSLK',
#  'customerid_1194-BHJYC',
#  'customerid_1194-HVAIF',
#  'customerid_1194-SPVSP',
#  'customerid_1195-OIYEJ',
#  'customerid_1196-AMORA',
#  'customerid_1197-BVMVG',
#  'customerid_1200-TUZHR',
#  'customerid_1202-KKGFU',
#  'customerid_1205-WNWPJ',
#  'customerid_1206-EHBDD',
#  'customerid_1207-BLKSA',
#  'customerid_1208-DNHLN',
#  'customerid_1208-NBVFH',
#  'customerid_1209-VFFOC',
#  'customerid_1212-GLHMD',
#  'customerid_1213-NGCUN',
#  'customerid_1215-EXRMO',
#  'customerid_1215-FIGMP',
#  'customerid_1215-VFYVK',
#  'customerid_1216-BGTSP',
#  'customerid_1216-JWVUX',
#  'customerid_1217-VASWC',
#  'customerid_1218-VKFPE',
#  'customerid_1219-NNDDO',
#  'customerid_1221-GHZEP',
#  'customerid_1222-KJNZD',
#  'customerid_1222-LRYKO',
#  'customerid_1223-UNPKS',
#  'customerid_1226-IENZN',
#  'customerid_1226-JZNKR',
#  'customerid_1226-UDFZR',
#  'customerid_1227-UDMZR',
#  'customerid_1228-FZFRV',
#  'customerid_1228-ZLNBX',
#  'customerid_1229-RCALF',
#  'customerid_1230-QAJDW',
#  'customerid_1231-YNDEK',
#  'customerid_1236-WFCDV',
#  'customerid_1237-WIYYZ',
#  'customerid_1240-HCBOH',
#  'customerid_1240-KNSEZ',
#  'customerid_1241-EZFMJ',
#  'customerid_1241-FPMOF',
#  'customerid_1245-HARPS',
#  'customerid_1247-QBVSH',
#  'customerid_1248-DYXUB',
#  'customerid_1251-KRREG',
#  'customerid_1251-STYSZ',
#  'customerid_1254-IZEYF',
#  'customerid_1257-SXUXQ',
#  'customerid_1258-YMZNM',
#  'customerid_1260-TTRXI',
#  'customerid_1261-FWTTE',
#  'customerid_1262-OPMFY',
#  'customerid_1264-BYWMS',
#  'customerid_1264-FUHCX',
#  'customerid_1265-BCFEO',
#  'customerid_1265-HVPZB',
#  'customerid_1265-XTECC',
#  'customerid_1265-ZFOSD',
#  'customerid_1266-NZYUI',
#  'customerid_1268-ASBGA',
#  'customerid_1269-FOYWN',
#  'customerid_1270-XKUCC',
#  'customerid_1271-SJBGZ',
#  'customerid_1271-UODNO',
#  'customerid_1272-ILHFG',
#  'customerid_1273-MTETI',
#  'customerid_1282-IHQAC',
#  'customerid_1285-OKIPP',
#  'customerid_1291-CUOCY',
#  'customerid_1293-BSEUN',
#  'customerid_1293-HHSHJ',
#  'customerid_1297-VQDRP',
#  'customerid_1298-PHBTI',
#  'customerid_1299-AURJA',
#  'customerid_1301-LOPVR',
#  'customerid_1302-TPUBN',
#  'customerid_1302-UHBDD',
#  'customerid_1303-SRDOK',
#  'customerid_1304-BCCFO',
#  'customerid_1304-NECVQ',
#  'customerid_1304-SEGFY',
#  'customerid_1306-RPWXZ',
#  'customerid_1307-ATKGB',
#  'customerid_1307-TVUFB',
#  'customerid_1309-BXVOQ',
#  'customerid_1309-XGFSN',
#  'customerid_1310-QRITU',
#  'customerid_1319-YLZJG',
#  'customerid_1320-GVNHT',
#  'customerid_1320-HTRDR',
#  'customerid_1320-REHCS',
#  'customerid_1322-AGOQM',
#  'customerid_1323-OOEPC',
#  'customerid_1324-NLTJE',
#  'customerid_1325-USMEC',
#  'customerid_1328-EUZHC',
#  'customerid_1329-VHWNP',
#  'customerid_1333-PBMXB',
#  'customerid_1334-FJSVR',
#  'customerid_1334-PDUKM',
#  'customerid_1335-HQMKX',
#  'customerid_1335-MXCSE',
#  'customerid_1335-NTIUC',
#  'customerid_1336-EZFZY',
#  'customerid_1337-BOZWO',
#  'customerid_1338-CECEE',
#  'customerid_1342-JPNKI',
#  'customerid_1343-EHPYB',
#  'customerid_1345-GKDZZ',
#  'customerid_1345-ZUKID',
#  'customerid_1346-PJWTK',
#  'customerid_1346-UFHAX',
#  'customerid_1347-KTTTA',
#  'customerid_1349-WXNGG',
#  'customerid_1352-HNSAW',
#  'customerid_1352-VHKAJ',
#  'customerid_1353-GHZOS',
#  'customerid_1353-LJWEM',
#  'customerid_1354-YZFNB',
#  'customerid_1355-KUSBG',
#  'customerid_1356-MKYSK',
#  'customerid_1357-BIJKI',
#  'customerid_1357-MVDOZ',
#  'customerid_1360-JYXKQ',
#  'customerid_1360-RCYRT',
#  'customerid_1360-XFJMR',
#  'customerid_1363-TXLSL',
#  'customerid_1370-GGAWX',
#  'customerid_1371-DWPAZ',
#  'customerid_1371-OJCEK',
#  'customerid_1371-WEPDS',
#  'customerid_1373-ORVIZ',
#  'customerid_1374-DMZUI',
#  'customerid_1376-HHBDV',
#  'customerid_1379-FRVEB',
#  'customerid_1383-EZRWL',
#  'customerid_1384-RCUXW',
#  'customerid_1385-TQOZW',
#  'customerid_1386-ZIKUV',
#  'customerid_1389-CXMLU',
#  'customerid_1389-WNUIB',
#  'customerid_1391-UBDAR',
#  'customerid_1393-IMKZG',
#  'customerid_1394-SUIUH',
#  'customerid_1395-OFUWC',
#  'customerid_1395-WSWXR',
#  'customerid_1396-QWFBJ',
#  'customerid_1397-XKKWR',
#  'customerid_1399-OUPJN',
#  'customerid_1399-UBQIU',
#  'customerid_1400-MMYXY',
#  'customerid_1400-WIVLL',
#  'customerid_1401-FTHFQ',
#  'customerid_1402-PTHGN',
#  'customerid_1403-GYAFU',
#  'customerid_1403-LKLIK',
#  'customerid_1406-PUQVY',
#  'customerid_1407-DIGZV',
#  'customerid_1409-PHXTF',
#  'customerid_1410-RSCMR',
#  'customerid_1414-YADCW',
#  'customerid_1415-YFWLT',
#  'customerid_1421-HCERK',
#  'customerid_1422-DGUBX',
#  'customerid_1423-BMPBQ',
#  'customerid_1427-VERSM',
#  'customerid_1428-GTBJJ',
#  'customerid_1428-IEDPR',
#  'customerid_1429-UYJSV',
#  'customerid_1430-SFQSA',
#  'customerid_1431-AIDJQ',
#  'customerid_1431-CYWMH',
#  'customerid_1432-FPAXX',
#  'customerid_1436-ZMJAN',
#  'customerid_1439-LCGVL',
#  'customerid_1442-BQPVU',
#  'customerid_1442-OKRJE',
#  'customerid_1444-VVSGW',
#  'customerid_1447-GIQMR',
#  'customerid_1447-PJGGA',
#  'customerid_1448-CYWKC',
#  'customerid_1448-PWKYE',
#  'customerid_1449-XQEMT',
#  'customerid_1450-GALXR',
#  ...]

# %%
df_encoded[['paymentmethod_Electronic check']].head()
# Out:
#    paymentmethod_Electronic check
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                            True

# %%
df_encoded = df_encoded.astype(int)

# %%
df_encoded[['paymentmethod_Electronic check']].head()
# Out:
#    paymentmethod_Electronic check
# 0                               1
# 1                               0
# 2                               0
# 3                               0
# 4                               1

# %% [markdown]
# ### One-Hot Encoding Verification
#
# - Encoding added new dummy columns for each category.
# - Encoded columns appear as **True/False**, which are equivalent to **1/0**.
# - Dataset shape increased after encoding, confirming categorical expansion.
# - Verified encoding using `.columns`, `.dtypes` checks.

# %% [markdown]
# SECTION 1.1
# - ✔ Handled missing values
# - ✔ Cleaned and standardized column names
# - ✔ Converted data types
# - ✔ Encoded categorical variables (One-Hot Encoding)

# %%
scaler = StandardScaler()
df_encoded[num_cols] = scaler.fit_transform(df_encoded[num_cols])

# %%
X = df_encoded.drop('churn', axis=1)
y = df_encoded['churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
X_train.to_csv("D:/customer_churn/data/processed/X_train.csv", index=False)
X_test.to_csv("D:/customer_churn/data/processed/X_test.csv", index=False)
y_train.to_csv("D:/customer_churn/data/processed/y_train.csv", index=False)
y_test.to_csv("D:/customer_churn/data/processed/y_test.csv", index=False)

print("Preprocessing complete. Files saved in /data/processed/")
# Out:
# Preprocessing complete. Files saved in /data/processed/

# %% [markdown]
# SECTION 1.2
# - ✔ Scaled numerical features (StandardScaler)
# - ✔ Created final feature matrix (X) and target vector (y)
# - ✔ Performed train–test split
# - ✔ Saved processed data for modeling

# %%
import joblib
joblib.dump(scaler, "D:/customer_churn/models/scaler.pkl")
# Out:
# ['D:/customer_churn/models/scaler.pkl']

# %%
joblib.dump(df_encoded.columns, "D:/customer_churn/models/columns.pkl")
# Out:
# ['D:/customer_churn/models/columns.pkl']

# %%
import joblib
columns = joblib.load("D:/customer_churn/models/columns.pkl")
columns
# Out:
# Index(['seniorcitizen', 'tenure', 'monthlycharges', 'totalcharges', 'churn',
#        'gender_Male', 'partner_Yes', 'dependents_Yes', 'phoneservice_Yes',
#        'multiplelines_No phone service', 'multiplelines_Yes',
#        'internetservice_Fiber optic', 'internetservice_No',
#        'onlinesecurity_No internet service', 'onlinesecurity_Yes',
#        'onlinebackup_No internet service', 'onlinebackup_Yes',
#        'deviceprotection_No internet service', 'deviceprotection_Yes',
#        'techsupport_No internet service', 'techsupport_Yes',
#        'streamingtv_No internet service', 'streamingtv_Yes',
#        'streamingmovies_No internet service', 'streamingmovies_Yes',
#        'contract_One year', 'contract_Two year', 'paperlessbilling_Yes',
#        'paymentmethod_Credit card (automatic)',
#        'paymentmethod_Electronic check', 'paymentmethod_Mailed check'],
#       dtype='object')
